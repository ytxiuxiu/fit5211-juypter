# %% [markdown]
# ### 1. Using the ADT class for points in 2-dimensional Euclidean space from before
#
# implement a function to generate a test set of n random nodes/points, where n is a user-definable parameter.

# %%
import math

class Node:
    """
    Geo-coded customer (node)
    """
    
    def __init__(self, key, x, y):
        self._key = key
        self._x = x
        self._y = y
        self._parent = None
        self._children = {}
        self._cluster = None
        
    @property
    def key(self):
        return self._key

    @property
    def x(self):
        return self._x
        
    @property
    def y(self):
        return self._y
    
    @property
    def parent(self):
        return self._parent
    
    @parent.setter
    def parent(self, node):
        self._parent = node
        
    @property
    def children(self):
        return self._children
    
    def addChild(self, node):
        self._children[node.key] = node
        
    def removeChild(self, node):
        del self._children[node.key]
        
    @property
    def cluster(self):
        return self.find()._cluster
    
    @cluster.setter
    def cluster(self, cluster):
        self._cluster = cluster
        
    def distanceTo(self, node):
        return math.sqrt(math.pow(node.x - self.x, 2) + math.pow(node.y - self.y, 2))
    
    def union(self, node):
        """
        Union this tree to another node
        
        Parameters:
            node (Node): Node to union to
        """
        self.parent = node
        node.addChild(self)
    
    def find(self):
        """
        Find the root of this tree
        
        Returns:
            Node: The root node
            
        """
        if self == self.parent:
            return self
        else:
            return self.parent.find()
    
    @property
    def descendants(self):
        """
        Get all descendants nodes of this node
        """
        return self._getDescendants([])
    
    def _getDescendants(self, descendants=[]):
        if self._children == []:
            return descendants
        else:
            for (key, child) in self._children.items():
                descendants.append(child)
                child._getDescendants(descendants)
        return descendants
    
    def printPretty(self, indent, isLast):
        """
        Print tree from this node prettily
        """
        print(indent, end='')
        if isLast:
            print('└╴', end='')
            indent += '   '
        else:
            print('├╴', end='')
            indent += '│  '
        print('Node {} ({}, {})'.format(self._key, self._x, self._y))
        
        i = 0
        for key, node in self._children.items():
            node.printPretty(indent, i == len(self._children) - 1)
            i += 1
        
    def __repr__(self):
        return '[Node key={}, children={}]'.format(self._key, self._children)

# %%
from random import randint

class Space:
    """
    ADT class for points in 2-dimensional Euclidean space
    """
    
    def __init__(self, minX, maxX, minY, maxY):
        """
        Initialise a space
        
        Parameters:
            minX (int): min x of this area
            maxX (int): max x of this area
            minY (int): min y of this area
            maxY (int): max y of this area
        """
        self._minX = minX
        self._maxX = maxX
        self._minY = minY
        self._maxY = maxY
        self._nodes = {}
        
    def generate(self, n):
        """
        Generate n nodes within in this area
        
        Parameters:
            n (int): Number of nodes
        """
        for i in range(0, n):
            self._nodes[i] = Node(i, randint(self._minX, self._maxX), randint(self._minY, self._maxY))
            
    @property
    def nodes(self):
        """
        Get all nodes in this space
        """
        return self._nodes
    
    def getNode(self, key):
        """
        Get a node with specific key
        
        Parameters:
            key (int): The key
        """
        return self._nodes[key]
            
    def __repr__(self):
        return self._nodes.__repr__()
    

s = Space(0, 100, 0, 100)
s.generate(10)

# %% [markdown]
# ### 2. Implement an ADT class for Partition (union-find).
#
# It must support the operations
# * for generating a new partition (i.e. a set of sets),
# * for generating a new set within the partition,
# * for merging two sets (union) and
# * for finding a set to which an element belongs (find).
#
# You should use the tree-based implementation.

# %%
class Cluster:
    """
    Cluster
    """
    
    def __init__(self, key, root):
        """
        Initialise a cluster
        
        Parameters:
            key (int): The key of this cluster
            root (Node): The root node of the tree in this cluster
        """
        self._key = key
        self._root = root
        self._rank = 0
    
    @property
    def key(self):
        return self._key
    
    @key.setter
    def key(self, key):
        self._key = key
        
    @property
    def root(self):
        return self._root
    
    @root.setter
    def root(self, root):
        self._root = root
        
    @property
    def rank(self):
        return self._rank
    
    @rank.setter
    def rank(self, rank):
        self._rank = rank
        
    def union(self, c):
        """
        Union this cluster with another cluster
        
        Parameters:
            c (Cluster): Another cluster
            
        Returns:
            Cluster: The cluster after union
        """
        if self.rank < c.rank:
            c.root.union(self.root)
            c.root = self.root
            self.rank = c.rank + 1
            return self
        else:
            self.root.union(c.root)
            self.root = c.root
            if self.rank == c.rank:
                c.rank += 1
            return c
        
    @property
    def nodes(self):
        """
        Get all nodes in this cluster
        """
        return [self._root] + self._root.descendants
                
    def __repr__(self):
        return '[Cluster key={}, root={}, rank={}]'.format(self._key, self._root, self._rank)

# %%
class Edge:
    """
    Edge connects two vertices (customers)
    """
    
    def __init__(self, vertexA, vertexB):
        self._vertexA = vertexA
        self._vertexB = vertexB
        
    @property
    def vertexA(self):
        return self._vertexA
    
    @property
    def vertexB(self):
        return self._vertexB
    
    @property
    def length(self):
        """
        Get the length of this edge
        """
        return self._vertexA.distanceTo(self._vertexB)
    
    def __repr__(self):
        return '[Edge vertexA={}, vertexB={}, length={}]'.format(self.vertexA, self.vertexB, self.length)

# %%
class Partition:
    """
    Partition
    """
    
    def __init__(self, nodes):
        """
        Generating a new partition
        
        Parameters:
            nodes ([Node]): Nodes within this partition
        """
        self._clusters = {}
        self._vertices = nodes
        self._edges = {}
        
        vertexList = list(nodes.values())
        for i in range(0, len(vertexList)):
            for j in range(i + 1, len(vertexList)):
                self._edges[(vertexList[i].key, vertexList[j].key)] = Edge(vertexList[i], vertexList[j])
        
    def generateCluster(self, key, root):
        """
        For generating a new set within the partition
        
        Parameters:
            key (int): The key of this cluster
            root (Node): The root node of the tree in this cluster
            
        Returns:
            Cluster: The cluster generated
        """
        root.parent = root
        c = Cluster(key, root)
        self._clusters[key] = c
        root.cluster = c
        return c
        
    def unionCluster(self, cA, cB):
        """
        For merging two sets (union)
        
        Parameters:
            cA (Cluster): Cluster A
            cB (Cluster): Cluster B
            
        Returns:
            Cluster: Cluster after union
        """
        c = cA.union(cB)
        
        if c.key == cA.key:
            if cB.key in self._clusters:
                del self._clusters[cB.key]
            cB.root.cluster = cA
        else:
            if cA.key in self._clusters:
                del self._clusters[cA.key]
            cA.root.cluster = cB
        return c
        
    def findCluster(self, node):
        """
        Finding a set to which an element belongs (find)
        
        Parameters:
            node (Node): The element
            
        Returns:
            Cluster: The cluster the element belongs
        """
        return node.find().cluster
    
    def printClusters(self):
        for key, cluster in self._clusters.items():
            print('Cluster {}:'.format(key))
            cluster.root.printPretty('', True)
        
    @property
    def clusters(self):
        """
        Get all clusters in the partition
        """
        return self._clusters

         
s = Space(0, 100, 0, 100)
s.generate(10)
p = Partition(s.nodes)

# %% [markdown]
# ### 3. Implement the clustering procedure described above.

# %%
def cluster(self):
    edges = sorted(list(self._edges.values()), key=lambda edge: edge.length)

    for i in range(0, len(self._vertices)):
        self.generateCluster(i, self._vertices[i])

    for i in range(0, len(edges)):
        edge = edges[i]
        if self.findCluster(edge.vertexA) != self.findCluster(edge.vertexB):
#             print()
#             print('== {} =========='.format(i))
#             self.printClusters()
            self.unionCluster(edge.vertexA.cluster, edge.vertexB.cluster)

    return self._clusters


Partition.cluster = cluster

s = Space(0, 100, 0, 100)
s.generate(10)
p = Partition(s.nodes)

p.cluster()
print()
print('== Result ==========')
p.printClusters()
# Out:
# == Result ==========
# Cluster 7:
# └╴Node 7 (53, 35)
#    ├╴Node 0 (77, 17)
#    │  └╴Node 2 (55, 12)
#    │     └╴Node 1 (44, 3)
#    ├╴Node 8 (8, 55)
#    │  ├╴Node 9 (20, 57)
#    │  │  └╴Node 6 (18, 59)
#    │  └╴Node 3 (33, 61)
#    └╴Node 5 (40, 95)
#       └╴Node 4 (71, 99)

# %% [markdown]
# ### 4. Extend your forest-based Partition ADT class from above with path compression

# %%
def findWithPathCompression(self):
    """
    Find the root of this tree with path compression

    Returns:
        Node: The root node

    """
    if self == self.parent:
        return self
    else:
        root = self.parent.find()
        self.parent.removeChild(self)
        self.parent = root
        root.addChild(self)
        return root

def findClusterWithPathCompression(self, node):
    """
    Finding a set to which an element belongs (find) with path compression

    Parameters:
        node (Node): The element

    Returns:
        Cluster: The cluster the element belongs
    """
    return node.findWithPathCompression().cluster



def clusterWithPathCompression(self):
    edges = sorted(list(self._edges.values()), key=lambda edge: edge.length)

    for i in range(0, len(self._vertices)):
        self.generateCluster(i, self._vertices[i])

    for i in range(0, len(edges)):
        edge = edges[i]
        if self.findClusterWithPathCompression(edge.vertexA) != self.findClusterWithPathCompression(edge.vertexB):
#             print()
#             print('== {} =========='.format(i))
#             self.printClusters()
            self.unionCluster(edge.vertexA.cluster, edge.vertexB.cluster)

    return self._clusters


Node.findWithPathCompression = findWithPathCompression

Partition.findClusterWithPathCompression = findClusterWithPathCompression
Partition.clusterWithPathCompression = clusterWithPathCompression


s = Space(0, 100, 0, 100)
s.generate(10)
p = Partition(s.nodes)

p.clusterWithPathCompression()
print()
print('== Result ==========')
p.printClusters()
# Out:
# == Result ==========
# Cluster 8:
# └╴Node 8 (35, 50)
#    ├╴Node 1 (42, 72)
#    ├╴Node 2 (84, 30)
#    ├╴Node 4 (24, 13)
#    ├╴Node 7 (85, 35)
#    ├╴Node 9 (25, 76)
#    ├╴Node 3 (92, 11)
#    ├╴Node 6 (80, 3)
#    ├╴Node 0 (41, 96)
#    └╴Node 5 (6, 1)

# %% [markdown]
# ### 5. Ultimately, we are aiming to find k-clusters
#
# i.e. we want to the electricity providers to see the structure of the micro-grid if they decide to commission k micro-grids such that all the nodes are covered in the vicinity of these sub-stations. Extend your implementation such that it stops when k clusters have been achieved and return those clusters, where k is a user-definable parameter

# %%
def kCluster(self, k):
    edges = sorted(list(self._edges.values()), key=lambda edge: edge.length)

    for i in range(0, len(self._vertices)):
        self.generateCluster(i, self._vertices[i])

    for i in range(0, len(edges)):
        edge = edges[i]
        if self.findClusterWithPathCompression(edge.vertexA) != self.findClusterWithPathCompression(edge.vertexB):
#             print()
#             print('== {} =========='.format(i))
#             self.printClusters()
            self.unionCluster(edge.vertexA.cluster, edge.vertexB.cluster)

            if len(self._clusters) == min(k, len(self._vertices)):
                break

    return self._clusters


Partition.kCluster = kCluster


s = Space(0, 100, 0, 100)
s.generate(10)
p = Partition(s.nodes)

p.kCluster(3)
print()
print('== Result ==========')
p.printClusters()
# Out:
# == Result ==========
# Cluster 4:
# └╴Node 4 (14, 87)
#    └╴Node 0 (40, 95)
# Cluster 6:
# └╴Node 6 (44, 10)
#    └╴Node 1 (64, 59)
#       ├╴Node 5 (82, 10)
#       │  ├╴Node 7 (96, 46)
#       │  ├╴Node 3 (83, 29)
#       │  └╴Node 9 (82, 43)
#       └╴Node 2 (60, 34)
# Cluster 8:
# └╴Node 8 (26, 51)

# %% [markdown]
# ### 6. Implement functions/methods to let the user query whether two given points (nodes) belong to the same cluster (micro-grid).

# %%
def isInTheSameClusterWith(self, node):
        """
        Check if this node is in the same cluster with another node
        
        Parameters:
            node (Node): Another node
            
        Returns:
            bool: If they are within the same cluster
        """
        return self.find().cluster == node.find().cluster


def isInTheSameCluster(self, nodeA, nodeB):
    return nodeA.isInTheSameClusterWith(nodeB)


Node.isInTheSameClusterWith = isInTheSameClusterWith

Partition.isInTheSameCluster = isInTheSameCluster


s = Space(0, 100, 0, 100)
s.generate(10)
p = Partition(s.nodes)

p.kCluster(3)

print()
print('== Result ==========')
p.printClusters()

print()
print(0, 1, p.isInTheSameCluster(s.getNode(0), s.getNode(1)))
print(1, 2, p.isInTheSameCluster(s.getNode(1), s.getNode(2)))
print(2, 3, p.isInTheSameCluster(s.getNode(2), s.getNode(3)))
print(3, 4, p.isInTheSameCluster(s.getNode(3), s.getNode(4)))
print(4, 5, p.isInTheSameCluster(s.getNode(4), s.getNode(5)))
print(5, 6, p.isInTheSameCluster(s.getNode(5), s.getNode(6)))
print(6, 7, p.isInTheSameCluster(s.getNode(6), s.getNode(7)))
print(7, 8, p.isInTheSameCluster(s.getNode(7), s.getNode(8)))
print(8, 9, p.isInTheSameCluster(s.getNode(8), s.getNode(9)))
print(9, 0, p.isInTheSameCluster(s.getNode(9), s.getNode(0)))
# Out:
# == Result ==========
# Cluster 4:
# └╴Node 4 (1, 78)
# Cluster 8:
# └╴Node 8 (87, 95)
# Cluster 9:
# └╴Node 9 (40, 87)
#    ├╴Node 3 (40, 69)
#    │  └╴Node 6 (34, 55)
#    ├╴Node 0 (40, 47)
#    └╴Node 7 (79, 47)
#       ├╴Node 5 (88, 49)
#       ├╴Node 2 (96, 49)
#       └╴Node 1 (64, 36)
#
# 0 1 True
# 1 2 True
# 2 3 True
# 3 4 False
# 4 5 False
# 5 6 True
# 6 7 True
# 7 8 False
# 8 9 False
# 9 0 True

# %% [markdown]
# ### 7. Define a function to compute the Dunn index, a measure for the quality of the clustering.

# %%
class NodeSet:
    """
    Node Set, for calculating closet distance within a set of nodes using divide and conquer approach
    """
    
    def __init__(self, nodes = None):
        if not nodes:
            self._nodes = []
        else:
            self._nodes = nodes
            
    def cons(self, node):
        return NodeSet([node] + self._nodes)
        
    def insert(self, node):
        self._nodes.append(node)
        
    def delete(self, i):
        del self._nodes[i]
        
    def isEmpty(self):
        return self._nodes == []
    
    def first(self):
        if self.isEmpty():
            return None
        else:
            return self._nodes[0]
    
    def last(self):
        if self.isEmpty():
            return None
        else:
            return self._nodes[self.length() - 1]
    
    def rest(self):
        return NodeSet(self._nodes[1:])
    
    def length(self):
        if self.isEmpty():
            return 0
        else: 
            return 1 + self.rest().length()
        
    def __repr__(self):
        return self._nodes.__repr__()
    
    def __iter__(self):
        return self._nodes.__iter__()
    
    def __getitem__(self, key):
        return self._nodes.__getitem__(key)
    
    def mergeX(self, other):
        if self.isEmpty():
            return other
        if other.isEmpty():
            return self

        if self.first().x <= other.first().x:
            return self.rest().mergeX(other).cons(self.first())
        else:
            return self.mergeX(other.rest()).cons(other.first())

    def mergeY(self, other):
        if self.isEmpty():
            return other
        if other.isEmpty():
            return self

        if self.first().y <= other.first().y:
            return self.rest().mergeY(other).cons(self.first())
        else:
            return self.mergeY(other.rest()).cons(other.first())

    def mergeSortX(self):
        if self.length() <= 1:
            return self

        mid = self.length() // 2
        firstHalf = NodeSet(self[:mid])
        lastHalf = NodeSet(self[mid:])
        return firstHalf.mergeSortX().mergeX(lastHalf.mergeSortX())

    def mergeSortY(self):
        if self.length() <= 1:
            return self

        mid = self.length() // 2
        firstHalf = NodeSet(self[:mid])
        lastHalf = NodeSet(self[mid:])
        return firstHalf.mergeSortY().mergeY(lastHalf.mergeSortY())
    
    def minDistanceBruteForce(self):
        dMin = float('Inf')
        for i in range(0, self.length()):
            for j in range(i + 1, self.length()):
                d = self[i].distanceTo(self[j])

                if d < dMin:
                    dMin = d

        return dMin

    def minDistanceDivideAndConquer(self):
        return self.mergeSortX()._minDistanceDivideAndConquer()

    def _minDistanceDivideAndConquer(self):
        if self.length() < 3:
            return self.minDistanceBruteForce()

        mid = self.length() // 2
        leftHalf = NodeSet(self[:mid])
        rightHalf = NodeSet(self[mid:])

        dLeft = leftHalf._minDistanceDivideAndConquer()
        dRight = rightHalf._minDistanceDivideAndConquer()

        if dLeft <= dRight:
            dMin = dLeft
        else:
            dMin = dRight

        midX = leftHalf.last().x
        l = NodeSet(leftHalf._pointsSearchFromRight(midX - dMin)._nodes + 
                     rightHalf._pointsSearchFromLeft(midX + dMin)._nodes).mergeSortY()

        for i in range(0, l.length()):
            dXMin = float('Inf')
            for j in range(i + 1, min(l.length(), i + 16)):
                dX = l[i].distanceTo(l[j])

                if dX < dXMin:
                    dXMin = dX

            if dXMin < dMin:
                dMin = dXMin

        return dMin

    def _pointsSearchFromRight(self, minX):
        if self.isEmpty():
            return NodeSet()

        if self.last().x >= minX:
            return NodeSet(self[:self.length() - 1]) \
                ._pointsSearchFromRight(minX).cons(self.last())
        else:
            return NodeSet(self[:self.length() - 1]) \
                ._pointsSearchFromRight(minX)

    def _pointsSearchFromLeft(self, maxX):
        if self.isEmpty():
            return NodeSet()

        if self.first().x <= maxX:
            return self.rest()._pointsSearchFromLeft(maxX).cons(self.first())
        else:
            return self.rest()._pointsSearchFromLeft(maxX)

# %%
def _getMaxDistanceOfCluster(self, cluster):
    edges = []
    for i in range(0, len(cluster.nodes)):
        for j in range(i + 1, len(cluster.nodes)):
            keyA = min(cluster.nodes[i].key, cluster.nodes[j].key)
            keyB = max(cluster.nodes[i].key, cluster.nodes[j].key)
            edges.append(self._edges[(keyA, keyB)])

    if len(edges) > 0:
        edges = sorted(edges, key=lambda edge: -edge.length)
        return edges[0].length
    else:
        return 0

def _getMaxDistance(self):
    distances = []
    for cluster in list(self._clusters.values()):
        distances.append(self._getMaxDistanceOfCluster(cluster))

    return max(distances)

def _getCentroidOfCluster(self, cluster):
    sumX = 0
    sumY = 0
    for node in cluster.nodes:
        sumX += node.x
        sumY += node.y

    return Node(None, sumX / len(cluster.nodes), sumY / len(cluster.nodes))

def _getMinInterClusterDistance(self):
    clusters = list(self._clusters.values())
    if len(clusters) <= 1:
        return 0

    centroids = []
    for cluster in clusters:
        centroids.append(self._getCentroidOfCluster(cluster))

    nodeSet = NodeSet(centroids)
    return nodeSet.minDistanceDivideAndConquer()

def getDunnIndex(self):
    maxDistance = self._getMaxDistance()
    if maxDistance != 0:
        return self._getMinInterClusterDistance() / maxDistance
    else:
        return float('inf')
    

Partition._getMaxDistanceOfCluster = _getMaxDistanceOfCluster
Partition._getMaxDistance = _getMaxDistance
Partition._getCentroidOfCluster = _getCentroidOfCluster
Partition._getMinInterClusterDistance = _getMinInterClusterDistance
Partition.getDunnIndex = getDunnIndex


s = Space(0, 100, 0, 100)
s.generate(10)
p = Partition(s.nodes)

p.kCluster(5)

print()
print('== Result ==========')
p.printClusters()

print()
print('dunnIndex = {}'.format(p.getDunnIndex()))
# Out:
# == Result ==========
# Cluster 3:
# └╴Node 3 (62, 86)
#    └╴Node 8 (86, 89)
#       └╴Node 2 (77, 73)
# Cluster 4:
# └╴Node 4 (31, 85)
# Cluster 5:
# └╴Node 5 (73, 46)
# Cluster 7:
# └╴Node 7 (11, 89)
# Cluster 9:
# └╴Node 9 (26, 36)
#    └╴Node 6 (43, 48)
#       └╴Node 1 (39, 22)
#          └╴Node 0 (51, 33)
#
# dunnIndex = 0.7753425496928191

# %% [markdown]
# ### 8. Compare the forest that you have generated for the k-clustering to the full minimum cost spanning tree.
#
# Give a brief, but precise characterization of the sets of edges that are in the MCST but not in the forest of the clustering.
#
# **ANSWER:**
#
# The n edges that are in the MCST but not in the forest of the clustering are the nth longest edges in the MCST.

# %% [markdown]
# ### Bonus.
#
# You could use Matplotlib or Bokeh to visualize how the algorithm works (i.e. visualize the point sets, the cluster connections as they emerge, and ultimately the results) and even to let the user interactively (graphically) enter a point set (the latter is easier in Matplotlib than in Bokeh).

# %%
def kClusterWithVisualisation(self, k, step):
    edges = sorted(list(self._edges.values()), key=lambda edge: edge.length)
    
    for edge in edges:
        print(edge)

    for i in range(0, len(self._vertices)):
        self.generateCluster(i, self._vertices[i])

    for i in range(0, len(edges)):
        edge = edges[i]
        if self.findCluster(edge.vertexA) != self.findCluster(edge.vertexB):
            self.unionCluster(edge.vertexA.cluster, edge.vertexB.cluster)

            if i >= step or len(self._clusters) == min(k, len(self._vertices)):
                return self._clusters, i

            
Partition.kClusterWithVisualisation = kClusterWithVisualisation

# %%
# %matplotlib inline
# %config InlineBackend.close_figures = False 

from pylab import *
import matplotlib.pyplot as plt
import numpy as np

from ipywidgets import widgets
from IPython.display import display, clear_output

rcParams['figure.figsize'] = (15, 8)

fontNode = {
    'family': 'serif',
    'color': 'darkred',
    'weight': 'normal',
    'size': 12
}

plt.ioff()
ax = plt.gca()

out = widgets.Output()
button = widgets.Button(description='Next')
vbox = widgets.VBox(children=(out, button))
display(vbox)

step = -1


# Generate nodes
s = Space(0, 100, 0, 100)
s.generate(20)


def displayConnection(node):
    for child in list(node.children.values()):
        plt.plot([node.x, child.x], [node.y, child.y])
        displayConnection(child)
    

def click(b):
    global step
    plt.cla()

    for point in list(s.nodes.values()):
        plt.plot(point.x, point.y, marker='o', markersize=3, color="red")
        plt.text(point.x, point.y, point.key, fontdict=fontNode)
    
    clusters = {}
    if step >= 0:
        p = Partition(s.nodes)
        clusters, step = p.kClusterWithVisualisation(3, step)
        
        for cluster in list(clusters.values()):
            plt.text(cluster.root.x - 4, cluster.root.y + 3, 'Cluster {}'.format(cluster.key), fontdict=fontNode)
            displayConnection(cluster.root)

    with out:
        clear_output(wait=True)
        display(ax.figure)
        
    if len(clusters) == 3:
        print('== Result ==========')
        p.printClusters()
        return
    
    step = step + 1

button.on_click(click)
click(None)
# Out:
# [Edge vertexA=[Node key=3, children={}], vertexB=[Node key=15, children={}], length=3.1622776601683795]
# [Edge vertexA=[Node key=0, children={}], vertexB=[Node key=18, children={}], length=4.242640687119285]
# [Edge vertexA=[Node key=0, children={}], vertexB=[Node key=5, children={}], length=8.246211251235321]
# [Edge vertexA=[Node key=8, children={}], vertexB=[Node key=12, children={}], length=8.602325267042627]
# [Edge vertexA=[Node key=13, children={}], vertexB=[Node key=17, children={}], length=9.433981132056603]
# [Edge vertexA=[Node key=1, children={}], vertexB=[Node key=14, children={}], length=9.848857801796104]
# [Edge vertexA=[Node key=5, children={}], vertexB=[Node key=18, children={}], length=12.083045973594572]
# [Edge vertexA=[Node key=10, children={}], vertexB=[Node key=15, children={}], length=12.206555615733702]
# [Edge vertexA=[Node key=10, children={}], vertexB=[Node key=16, children={}], length=12.36931687685298]
# [Edge vertexA=[Node key=1, children={}], vertexB=[Node key=19, children={}], length=12.727922061357855]
# [Edge vertexA=[Node key=14, children={}], vertexB=[Node key=18, children={}], length=13.0]
# [Edge vertexA=[Node key=3, children={}], vertexB=[Node key=10, children={}], length=14.317821063276353]
# [Edge vertexA=[Node key=3, children={}], vertexB=[Node key=12, children={}], length=16.15549442140351]
# [Edge vertexA=[Node key=12, children={}], vertexB=[Node key=15, children={}], length=16.64331697709324]
# [Edge vertexA=[Node key=0, children={}], vertexB=[Node key=14, children={}], length=17.0]
# [Edge vertexA=[Node key=9, children={}], vertexB=[Node key=19, children={}], length=18.027756377319946]
# [Edge vertexA=[Node key=14, children={}], vertexB=[Node key=19, children={}], length=18.681541692269406]
# [Edge vertexA=[Node key=2, children={}], vertexB=[Node key=17, children={}], length=19.4164878389476]
# [Edge vertexA=[Node key=7, children={}], vertexB=[Node key=16, children={}], length=20.223748416156685]
# [Edge vertexA=[Node key=9, children={}], vertexB=[Node key=11, children={}], length=20.248456731316587]
# [Edge vertexA=[Node key=5, children={}], vertexB=[Node key=7, children={}], length=20.808652046684813]
# [Edge vertexA=[Node key=1, children={}], vertexB=[Node key=18, children={}], length=21.02379604162864]
# [Edge vertexA=[Node key=8, children={}], vertexB=[Node key=11, children={}], length=21.2602916254693]
# [Edge vertexA=[Node key=9, children={}], vertexB=[Node key=14, children={}], length=21.540659228538015]
# [Edge vertexA=[Node key=11, children={}], vertexB=[Node key=12, children={}], length=22.135943621178654]
# [Edge vertexA=[Node key=4, children={}], vertexB=[Node key=11, children={}], length=22.80350850198276]
# [Edge vertexA=[Node key=3, children={}], vertexB=[Node key=9, children={}], length=22.825424421026653]
# [Edge vertexA=[Node key=1, children={}], vertexB=[Node key=9, children={}], length=24.020824298928627]
# [Edge vertexA=[Node key=15, children={}], vertexB=[Node key=16, children={}], length=24.166091947189145]
# [Edge vertexA=[Node key=0, children={}], vertexB=[Node key=1, children={}], length=24.331050121192877]
# [Edge vertexA=[Node key=3, children={}], vertexB=[Node key=8, children={}], length=24.596747752497688]
# [Edge vertexA=[Node key=4, children={}], vertexB=[Node key=19, children={}], length=25.0]
# [Edge vertexA=[Node key=5, children={}], vertexB=[Node key=14, children={}], length=25.079872407968907]
# [Edge vertexA=[Node key=8, children={}], vertexB=[Node key=15, children={}], length=25.238858928247925]
# [Edge vertexA=[Node key=4, children={}], vertexB=[Node key=9, children={}], length=25.495097567963924]
# [Edge vertexA=[Node key=9, children={}], vertexB=[Node key=15, children={}], length=25.942243542145693]
# [Edge vertexA=[Node key=3, children={}], vertexB=[Node key=16, children={}], length=26.570660511172846]
# [Edge vertexA=[Node key=0, children={}], vertexB=[Node key=7, children={}], length=26.92582403567252]
# [Edge vertexA=[Node key=7, children={}], vertexB=[Node key=10, children={}], length=27.459060435491963]
# [Edge vertexA=[Node key=3, children={}], vertexB=[Node key=11, children={}], length=28.160255680657446]
# [Edge vertexA=[Node key=10, children={}], vertexB=[Node key=12, children={}], length=28.319604517012593]
# [Edge vertexA=[Node key=2, children={}], vertexB=[Node key=13, children={}], length=28.460498941515414]
# [Edge vertexA=[Node key=7, children={}], vertexB=[Node key=18, children={}], length=28.861739379323623]
# [Edge vertexA=[Node key=6, children={}], vertexB=[Node key=17, children={}], length=29.154759474226502]
# [Edge vertexA=[Node key=9, children={}], vertexB=[Node key=12, children={}], length=29.5296461204668]
# [Edge vertexA=[Node key=2, children={}], vertexB=[Node key=12, children={}], length=30.528675044947494]
# [Edge vertexA=[Node key=11, children={}], vertexB=[Node key=15, children={}], length=30.805843601498726]
# [Edge vertexA=[Node key=18, children={}], vertexB=[Node key=19, children={}], length=31.622776601683793]
# [Edge vertexA=[Node key=9, children={}], vertexB=[Node key=18, children={}], length=32.01562118716424]
# [Edge vertexA=[Node key=6, children={}], vertexB=[Node key=13, children={}], length=32.14031735997639]
# [Edge vertexA=[Node key=2, children={}], vertexB=[Node key=8, children={}], length=32.28002478313795]
# [Edge vertexA=[Node key=1, children={}], vertexB=[Node key=5, children={}], length=32.55764119219941]
# [Edge vertexA=[Node key=10, children={}], vertexB=[Node key=18, children={}], length=32.69556544854363]
# [Edge vertexA=[Node key=3, children={}], vertexB=[Node key=14, children={}], length=33.24154027718932]
# [Edge vertexA=[Node key=9, children={}], vertexB=[Node key=10, children={}], length=33.37663853655727]
# [Edge vertexA=[Node key=11, children={}], vertexB=[Node key=19, children={}], length=34.132096331752024]
# [Edge vertexA=[Node key=8, children={}], vertexB=[Node key=9, children={}], length=34.20526275297414]
# [Edge vertexA=[Node key=0, children={}], vertexB=[Node key=10, children={}], length=34.48187929913333]
# [Edge vertexA=[Node key=2, children={}], vertexB=[Node key=15, children={}], length=34.48187929913333]
# [Edge vertexA=[Node key=5, children={}], vertexB=[Node key=16, children={}], length=34.92849839314596]
# [Edge vertexA=[Node key=5, children={}], vertexB=[Node key=10, children={}], length=35.05709628591621]
# [Edge vertexA=[Node key=14, children={}], vertexB=[Node key=15, children={}], length=35.34119409414458]
# [Edge vertexA=[Node key=10, children={}], vertexB=[Node key=14, children={}], length=35.35533905932738]
# [Edge vertexA=[Node key=0, children={}], vertexB=[Node key=19, children={}], length=35.4682957019364]
# [Edge vertexA=[Node key=3, children={}], vertexB=[Node key=18, children={}], length=36.0]
# [Edge vertexA=[Node key=0, children={}], vertexB=[Node key=9, children={}], length=36.235341863986875]
# [Edge vertexA=[Node key=16, children={}], vertexB=[Node key=18, children={}], length=36.796738985948195]
# [Edge vertexA=[Node key=8, children={}], vertexB=[Node key=10, children={}], length=36.87817782917155]
# [Edge vertexA=[Node key=2, children={}], vertexB=[Node key=3, children={}], length=36.89173349139343]
# [Edge vertexA=[Node key=15, children={}], vertexB=[Node key=18, children={}], length=37.12142238654117]
# [Edge vertexA=[Node key=0, children={}], vertexB=[Node key=16, children={}], length=37.20215047547655]
# [Edge vertexA=[Node key=1, children={}], vertexB=[Node key=4, children={}], length=37.64306044943742]
# [Edge vertexA=[Node key=2, children={}], vertexB=[Node key=10, children={}], length=37.656340767525464]
# [Edge vertexA=[Node key=2, children={}], vertexB=[Node key=6, children={}], length=37.8021163428716]
# [Edge vertexA=[Node key=13, children={}], vertexB=[Node key=16, children={}], length=38.01315561749642]
# [Edge vertexA=[Node key=16, children={}], vertexB=[Node key=17, children={}], length=38.62641583165593]
# [Edge vertexA=[Node key=7, children={}], vertexB=[Node key=15, children={}], length=39.05124837953327]
# [Edge vertexA=[Node key=0, children={}], vertexB=[Node key=3, children={}], length=39.11521443121589]
# [Edge vertexA=[Node key=12, children={}], vertexB=[Node key=16, children={}], length=39.20459156782532]
# [Edge vertexA=[Node key=3, children={}], vertexB=[Node key=19, children={}], length=39.698866482558415]
# [Edge vertexA=[Node key=0, children={}], vertexB=[Node key=15, children={}], length=40.0]
# [Edge vertexA=[Node key=7, children={}], vertexB=[Node key=14, children={}], length=40.049968789001575]
# [Edge vertexA=[Node key=2, children={}], vertexB=[Node key=16, children={}], length=40.311288741492746]
# [Edge vertexA=[Node key=3, children={}], vertexB=[Node key=7, children={}], length=40.311288741492746]
# [Edge vertexA=[Node key=1, children={}], vertexB=[Node key=3, children={}], length=40.8166632639171]
# [Edge vertexA=[Node key=4, children={}], vertexB=[Node key=14, children={}], length=41.400483088968905]
# [Edge vertexA=[Node key=11, children={}], vertexB=[Node key=14, children={}], length=41.78516483155236]
# [Edge vertexA=[Node key=10, children={}], vertexB=[Node key=17, children={}], length=42.01190307520001]
# [Edge vertexA=[Node key=10, children={}], vertexB=[Node key=11, children={}], length=42.37924020083418]
# [Edge vertexA=[Node key=3, children={}], vertexB=[Node key=5, children={}], length=42.44997055358225]
# [Edge vertexA=[Node key=15, children={}], vertexB=[Node key=19, children={}], length=42.638011210655684]
# [Edge vertexA=[Node key=5, children={}], vertexB=[Node key=15, children={}], length=42.7551166528639]
# [Edge vertexA=[Node key=14, children={}], vertexB=[Node key=16, children={}], length=43.04648650006177]
# [Edge vertexA=[Node key=5, children={}], vertexB=[Node key=9, children={}], length=43.139309220245984]
# [Edge vertexA=[Node key=1, children={}], vertexB=[Node key=15, children={}], length=43.266615305567875]
# [Edge vertexA=[Node key=1, children={}], vertexB=[Node key=11, children={}], length=43.41658669218482]
# [Edge vertexA=[Node key=5, children={}], vertexB=[Node key=19, children={}], length=43.657759905886145]
# [Edge vertexA=[Node key=4, children={}], vertexB=[Node key=8, children={}], length=44.04543109109048]
# [Edge vertexA=[Node key=10, children={}], vertexB=[Node key=13, children={}], length=44.04543109109048]
# [Edge vertexA=[Node key=4, children={}], vertexB=[Node key=12, children={}], length=44.294469180700204]
# [Edge vertexA=[Node key=15, children={}], vertexB=[Node key=17, children={}], length=44.40720662234904]
# [Edge vertexA=[Node key=1, children={}], vertexB=[Node key=10, children={}], length=44.68780594300866]
# [Edge vertexA=[Node key=9, children={}], vertexB=[Node key=16, children={}], length=45.044422518220834]
# [Edge vertexA=[Node key=3, children={}], vertexB=[Node key=4, children={}], length=45.39823785126467]
# [Edge vertexA=[Node key=12, children={}], vertexB=[Node key=14, children={}], length=46.389654018972806]
# [Edge vertexA=[Node key=12, children={}], vertexB=[Node key=17, children={}], length=46.57252408878007]
# [Edge vertexA=[Node key=10, children={}], vertexB=[Node key=19, children={}], length=47.4236228055175]
# [Edge vertexA=[Node key=3, children={}], vertexB=[Node key=17, children={}], length=47.43416490252569]
# [Edge vertexA=[Node key=8, children={}], vertexB=[Node key=16, children={}], length=47.50789408087881]
# [Edge vertexA=[Node key=12, children={}], vertexB=[Node key=19, children={}], length=47.50789408087881]
# [Edge vertexA=[Node key=4, children={}], vertexB=[Node key=15, children={}], length=48.507731342539614]
# [Edge vertexA=[Node key=13, children={}], vertexB=[Node key=15, children={}], length=48.75448697299562]
# [Edge vertexA=[Node key=1, children={}], vertexB=[Node key=7, children={}], length=49.36598018878993]
# [Edge vertexA=[Node key=8, children={}], vertexB=[Node key=17, children={}], length=50.24937810560445]
# [Edge vertexA=[Node key=7, children={}], vertexB=[Node key=9, children={}], length=51.264022471905186]
# [Edge vertexA=[Node key=12, children={}], vertexB=[Node key=18, children={}], length=51.35172830587107]
# [Edge vertexA=[Node key=8, children={}], vertexB=[Node key=19, children={}], length=51.62363799656123]
# [Edge vertexA=[Node key=11, children={}], vertexB=[Node key=18, children={}], length=51.62363799656123]
# [Edge vertexA=[Node key=3, children={}], vertexB=[Node key=13, children={}], length=51.894122981316485]
# [Edge vertexA=[Node key=1, children={}], vertexB=[Node key=12, children={}], length=52.20153254455275]
# [Edge vertexA=[Node key=2, children={}], vertexB=[Node key=11, children={}], length=52.32590180780452]
# [Edge vertexA=[Node key=1, children={}], vertexB=[Node key=16, children={}], length=52.839379254491625]
# [Edge vertexA=[Node key=8, children={}], vertexB=[Node key=14, children={}], length=53.009433122794285]
# [Edge vertexA=[Node key=12, children={}], vertexB=[Node key=13, children={}], length=53.46026561849464]
# [Edge vertexA=[Node key=4, children={}], vertexB=[Node key=18, children={}], length=54.08326913195984]
# [Edge vertexA=[Node key=7, children={}], vertexB=[Node key=13, children={}], length=54.42425929675111]
# [Edge vertexA=[Node key=11, children={}], vertexB=[Node key=16, children={}], length=54.70831746635972]
# [Edge vertexA=[Node key=0, children={}], vertexB=[Node key=12, children={}], length=54.74486277268398]
# [Edge vertexA=[Node key=7, children={}], vertexB=[Node key=12, children={}], length=55.60575509783138]
# [Edge vertexA=[Node key=0, children={}], vertexB=[Node key=11, children={}], length=55.758407437802596]
# [Edge vertexA=[Node key=7, children={}], vertexB=[Node key=17, children={}], length=57.0701322935211]
# [Edge vertexA=[Node key=16, children={}], vertexB=[Node key=19, children={}], length=57.56735185849702]
# [Edge vertexA=[Node key=1, children={}], vertexB=[Node key=8, children={}], length=57.87054518492115]
# [Edge vertexA=[Node key=2, children={}], vertexB=[Node key=9, children={}], length=58.0]
# [Edge vertexA=[Node key=4, children={}], vertexB=[Node key=10, children={}], length=58.0]
# [Edge vertexA=[Node key=8, children={}], vertexB=[Node key=13, children={}], length=58.0]
# [Edge vertexA=[Node key=7, children={}], vertexB=[Node key=19, children={}], length=58.077534382926416]
# [Edge vertexA=[Node key=0, children={}], vertexB=[Node key=4, children={}], length=58.249463516842795]
# [Edge vertexA=[Node key=5, children={}], vertexB=[Node key=12, children={}], length=58.52349955359813]
# [Edge vertexA=[Node key=8, children={}], vertexB=[Node key=18, children={}], length=59.033888572581766]
# [Edge vertexA=[Node key=2, children={}], vertexB=[Node key=7, children={}], length=60.530983801686226]
# [Edge vertexA=[Node key=5, children={}], vertexB=[Node key=11, children={}], length=62.00806399170998]
# [Edge vertexA=[Node key=0, children={}], vertexB=[Node key=8, children={}], length=62.5859409132754]
# [Edge vertexA=[Node key=7, children={}], vertexB=[Node key=8, children={}], length=64.20280367709809]
# [Edge vertexA=[Node key=4, children={}], vertexB=[Node key=5, children={}], length=66.03786792439622]
# [Edge vertexA=[Node key=7, children={}], vertexB=[Node key=11, children={}], length=66.2872536767062]
# [Edge vertexA=[Node key=5, children={}], vertexB=[Node key=8, children={}], length=66.73080248281148]
# [Edge vertexA=[Node key=6, children={}], vertexB=[Node key=16, children={}], length=67.77905281132217]
# [Edge vertexA=[Node key=6, children={}], vertexB=[Node key=12, children={}], length=68.24221567329127]
# [Edge vertexA=[Node key=11, children={}], vertexB=[Node key=17, children={}], length=68.6804193347711]
# [Edge vertexA=[Node key=6, children={}], vertexB=[Node key=8, children={}], length=68.8839603971781]
# [Edge vertexA=[Node key=2, children={}], vertexB=[Node key=14, children={}], length=69.77105417004964]
# [Edge vertexA=[Node key=2, children={}], vertexB=[Node key=18, children={}], length=69.92138442565336]
# [Edge vertexA=[Node key=4, children={}], vertexB=[Node key=16, children={}], length=70.06425622241343]
# [Edge vertexA=[Node key=9, children={}], vertexB=[Node key=17, children={}], length=70.178344238091]
# [Edge vertexA=[Node key=6, children={}], vertexB=[Node key=10, children={}], length=70.49113419430843]
# [Edge vertexA=[Node key=6, children={}], vertexB=[Node key=15, children={}], length=70.83784299369935]
# [Edge vertexA=[Node key=0, children={}], vertexB=[Node key=2, children={}], length=72.03471385380801]
# [Edge vertexA=[Node key=2, children={}], vertexB=[Node key=5, children={}], length=72.56031973468694]
# [Edge vertexA=[Node key=5, children={}], vertexB=[Node key=13, children={}], length=72.56031973468694]
# [Edge vertexA=[Node key=5, children={}], vertexB=[Node key=17, children={}], length=73.53910524340094]
# [Edge vertexA=[Node key=3, children={}], vertexB=[Node key=6, children={}], length=73.59347797189639]
# [Edge vertexA=[Node key=17, children={}], vertexB=[Node key=18, children={}], length=74.09453421137081]
# [Edge vertexA=[Node key=13, children={}], vertexB=[Node key=18, children={}], length=74.65252842335616]
# [Edge vertexA=[Node key=9, children={}], vertexB=[Node key=13, children={}], length=74.68600939935136]
# [Edge vertexA=[Node key=2, children={}], vertexB=[Node key=4, children={}], length=74.79304780526061]
# [Edge vertexA=[Node key=0, children={}], vertexB=[Node key=17, children={}], length=75.17978451685]
# [Edge vertexA=[Node key=0, children={}], vertexB=[Node key=13, children={}], length=75.21303078589507]
# [Edge vertexA=[Node key=11, children={}], vertexB=[Node key=13, children={}], length=75.31268153505093]
# [Edge vertexA=[Node key=2, children={}], vertexB=[Node key=19, children={}], length=75.82216034906945]
# [Edge vertexA=[Node key=4, children={}], vertexB=[Node key=7, children={}], length=76.53757247260981]
# [Edge vertexA=[Node key=14, children={}], vertexB=[Node key=17, children={}], length=77.23341245859851]
# [Edge vertexA=[Node key=1, children={}], vertexB=[Node key=2, children={}], length=77.69813382572325]
# [Edge vertexA=[Node key=13, children={}], vertexB=[Node key=14, children={}], length=79.30952023559341]
# [Edge vertexA=[Node key=6, children={}], vertexB=[Node key=7, children={}], length=85.86617494683223]
# [Edge vertexA=[Node key=1, children={}], vertexB=[Node key=17, children={}], length=86.27861844049197]
# [Edge vertexA=[Node key=17, children={}], vertexB=[Node key=19, children={}], length=87.00574693662483]
# [Edge vertexA=[Node key=1, children={}], vertexB=[Node key=13, children={}], length=88.72992730753249]
# [Edge vertexA=[Node key=6, children={}], vertexB=[Node key=11, children={}], length=89.69392398596462]
# [Edge vertexA=[Node key=4, children={}], vertexB=[Node key=17, children={}], length=90.24965373894794]
# [Edge vertexA=[Node key=13, children={}], vertexB=[Node key=19, children={}], length=90.7358804442873]
# [Edge vertexA=[Node key=6, children={}], vertexB=[Node key=9, children={}], length=95.524865872714]
# [Edge vertexA=[Node key=4, children={}], vertexB=[Node key=13, children={}], length=96.16652224137046]
# [Edge vertexA=[Node key=5, children={}], vertexB=[Node key=6, children={}], length=102.69371937952194]
# [Edge vertexA=[Node key=6, children={}], vertexB=[Node key=18, children={}], length=102.95630140987001]
# [Edge vertexA=[Node key=0, children={}], vertexB=[Node key=6, children={}], length=104.20172743289815]
# [Edge vertexA=[Node key=6, children={}], vertexB=[Node key=14, children={}], length=105.20931517693668]
# [Edge vertexA=[Node key=4, children={}], vertexB=[Node key=6, children={}], length=112.36102527122117]
# [Edge vertexA=[Node key=6, children={}], vertexB=[Node key=19, children={}], length=113.13708498984761]
# [Edge vertexA=[Node key=1, children={}], vertexB=[Node key=6, children={}], length=113.85077953180645]
